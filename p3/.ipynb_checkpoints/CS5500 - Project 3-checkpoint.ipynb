# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data.csv")
df
# Out:
#     n  local_list  mutex_lock  cpu_pinned    k  num_threads  time1  time2  \
# 0   0           0           0           0  200            2    257    257
# 1   0           0           0           0  400            2    237    237
# 2   0           0           0           0  800            2    395    395
# 3   0           0           0           0  200            4    596    596
# 4   0           0           0           0  400            4   1013   1013
# .. ..         ...         ...         ...  ...          ...    ...    ...
# 67  3           0           0           1  400           32   5091   5091
# 68  3           0           0           1  800           32   3462   3462
# 69  3           0           0           1  200           64  12053  12053
# 70  3           0           0           1  400           64   4332   4332
# 71  3           0           0           1  800           64   6131   6131
#
#     time3
# 0     257
# 1     237
# 2     395
# 3     596
# 4    1013
# ...

# %%
df = pd.melt(df, id_vars=['n', 'local_list', 'mutex_lock', 'cpu_pinned', 'k', 'num_threads'], value_vars=['time1', 'time2', 'time3'], var_name='run', value_name='time')
df = df.drop(['local_list', 'mutex_lock', 'cpu_pinned'], axis=1)
df = df.groupby(['n', 'k', 'num_threads']).mean().reset_index()
df['n'] = df.n.map({0:'Baseline', 1: 'Local List', 2: 'Mutex Lock', 3: 'CPU Pinned'})
df
# Out:
# C:\Users\DFCS-General\AppData\Local\Temp\ipykernel_8020\3612194035.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df = df.groupby(['n', 'k', 'num_threads']).mean().reset_index()
#              n    k  num_threads    time
# 0     Baseline  200            2   257.0
# 1     Baseline  200            4   596.0
# 2     Baseline  200            8   770.0
# 3     Baseline  200           16  1847.0
# 4     Baseline  200           32  5837.0
# ..         ...  ...          ...     ...
# 67  CPU Pinned  800            4   358.0
# 68  CPU Pinned  800            8   580.0
# 69  CPU Pinned  800           16  2841.0
# 70  CPU Pinned  800           32  3462.0
# 71  CPU Pinned  800           64  6131.0
#
# [72 rows x 4 columns]

# %%
sns.barplot(data=df, x='n', y='time')
plt.show()
